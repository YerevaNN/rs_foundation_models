# %%
# LEVID-CD

import matplotlib.pyplot as plt
from scipy.integrate import trapz


# Data points
x_values = [0, 1/8, 1/4, 1/2, 1]


y_values_ibot_imagenet = [0, 0.026, 0.546, 0.882, 0.909] 
y_values_ibot_milaid = [0, 0.054, 0.518, 0.879, 0.907]
y_values_gfm = [0, 0.050, 0.757, 0.890, 0.906]
y_values_satlas = [0, 0.125, 0.578, 0.866, 0.887 ]


# iBOT-ImageNet & 90.9 & 88.2 & 54.6 & 2.6 & 66.36 
# iBOT-MillionAID & 90.7 & 87.9 & 51.8 & 5.4 & 66.03
# GFM & 90.6 & 89.0 & 75.7 & 5.0 & 70.84
# SatlasPretrain (Sentinel2\_SwinB\_SI\_RGB) & 88.7 & 86.6 & 57.8 & 12.5 & 67.05


# Sort together by x-values
# sorted_data = sorted(zip(x_values, y_values))
# x_values, y_values = zip(*sorted_data)

# Calculate AUC using trapezoidal rule
auc_ibot_imagenet = trapz(y_values_ibot_imagenet, x_values)
auc_ibot_milaid = trapz(y_values_ibot_milaid, x_values)
auc_gfm = trapz(y_values_gfm, x_values)
auc_satlas = trapz(y_values_satlas, x_values)

# auc_satlas = trapz(y_values_satlas, x_values)

plt.figure(figsize=(4, 4))

# Plot the curve and points
plt.plot(x_values, y_values_ibot_imagenet, label=f"iBOT-ImageNet ({auc_ibot_imagenet:.3f})", marker='o', color='blue', linestyle='-')
plt.plot(x_values, y_values_ibot_milaid, label=f"iBOT-MillionAID ({auc_ibot_milaid:.3f})", marker='o', color='orange', linestyle='-')
plt.plot(x_values, y_values_satlas, label=f"SatlasPretrain ({auc_satlas:.3f})", marker='o', color='green', linestyle='-')
plt.plot(x_values, y_values_gfm, label=f"GFM ({auc_gfm:.3f})", marker='o', color='red', linestyle='-')

# plt.plot(x_values, y_values_satlas, label=f"SATLAS ({auc_satlas:.3f})", marker='o')
# plt.scatter(x_values, y_values, label="Data Points")

# Add labels and title
plt.xlabel("Scale")
plt.ylabel("Micro-F1")
plt.title("LEVIR-CD")

# Show AUC value
# plt.text(0.7, 0.1, f"AUC: {auc:.3f}", ha="center", va="center", color='C0')
# plt.text(0.2, 0.4, f"AUC: {auc_aug:.3f}", ha="center", va="center", color='C1')

plt.legend(bbox_to_anchor=(0.05, -0.2), loc='upper left') 

# plt.legend(loc='outer')
plt.grid(True)
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.savefig('change_levir.pdf', bbox_inches='tight') 
plt.show()
# Out:
# /tmp/ipykernel_2027803/1508753197.py:28: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_ibot_imagenet = trapz(y_values_ibot_imagenet, x_values)
# /tmp/ipykernel_2027803/1508753197.py:29: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_ibot_milaid = trapz(y_values_ibot_milaid, x_values)
# /tmp/ipykernel_2027803/1508753197.py:30: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_gfm = trapz(y_values_gfm, x_values)
# /tmp/ipykernel_2027803/1508753197.py:31: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_satlas = trapz(y_values_satlas, x_values)

# %%
# CDD


# Data points
x_values = [0, 1/8, 1/4, 1/2, 1]


y_values_ibot_imagenet = [0, 0.757, 0.877, 0.963, 0.971]
y_values_ibot_milaid = [0, 0.790, 0.905, 0.966, 0.971]
y_values_satlas = [0, 0.837, 0.903, 0.952, 0.962]
y_values_gfm = [0, 0.762, 0.872, 0.959, 0.969]

# iBOT-ImageNet & 97.1 & 96.3 & 87.7 & 75.7 & 86.29 \\
# iBOT-MillionAID & 97.1 & 96.6 & 90.5 & 79.0 & 87.34 \\
# SatlasPretrain (Sentinel2\_SwinB\_SI\_RGB) & 96.2 & 95.2 & 90.3 & 83.7 & 87.14 \\
# GFM & 96.9 & 95.9 & 87.2 & 76.2 & 86.06 \\


# Sort together by x-values
# sorted_data = sorted(zip(x_values, y_values))
# x_values, y_values = zip(*sorted_data)

# Calculate AUC using trapezoidal rule
auc_ibot_imagenet = trapz(y_values_ibot_imagenet, x_values)
auc_ibot_milaid = trapz(y_values_ibot_milaid, x_values)
auc_gfm = trapz(y_values_gfm, x_values)
auc_satlas = trapz(y_values_satlas, x_values)

# auc_satlas = trapz(y_values_satlas, x_values)

plt.figure(figsize=(4, 4))

# Plot the curve and points
plt.plot(x_values, y_values_ibot_imagenet, label=f"iBOT-ImageNet ({auc_ibot_imagenet:.3f})", marker='o', color='blue', linestyle='-')
plt.plot(x_values, y_values_ibot_milaid, label=f"iBOT-MillionAID ({auc_ibot_milaid:.3f})", marker='o', color='orange', linestyle='-')
plt.plot(x_values, y_values_satlas, label=f"SatlasPretrain ({auc_satlas:.3f})", marker='o', color='green', linestyle='-')
plt.plot(x_values, y_values_gfm, label=f"GFM ({auc_gfm:.3f})", marker='o', color='red', linestyle='-')

# plt.plot(x_values, y_values_satlas, label=f"SATLAS ({auc_satlas:.3f})", marker='o')
# plt.scatter(x_values, y_values, label="Data Points")

# Add labels and title
plt.xlabel("Scale")
plt.ylabel("Micro-F1")
plt.title("CDD")

# Show AUC value
# plt.text(0.7, 0.1, f"AUC: {auc:.3f}", ha="center", va="center", color='C0')
# plt.text(0.2, 0.4, f"AUC: {auc_aug:.3f}", ha="center", va="center", color='C1')

plt.legend(bbox_to_anchor=(0.05, -0.2), loc='upper left') 

# plt.legend(loc='outer')
plt.grid(True)
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.savefig('change_cdd.pdf', bbox_inches='tight') 
plt.show()
# Out:
# /tmp/ipykernel_2027803/183867595.py:24: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_ibot_imagenet = trapz(y_values_ibot_imagenet, x_values)
# /tmp/ipykernel_2027803/183867595.py:25: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_ibot_milaid = trapz(y_values_ibot_milaid, x_values)
# /tmp/ipykernel_2027803/183867595.py:26: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_gfm = trapz(y_values_gfm, x_values)
# /tmp/ipykernel_2027803/183867595.py:27: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_satlas = trapz(y_values_satlas, x_values)

# %%
# RESISC45

import matplotlib.pyplot as plt
from scipy.integrate import trapz

# Data points
x_values = [0, 1/8, 1/4, 1/2, 1]

# y_values_ibot_milaid = [0, 0.117, 0.510, 0.983, 0.988]
# y_values_gfm = [0, 0.433, 0.781, 0.914, 0.948]
# y_values_ibot_imagenet = [0, 0.652, 0.905, 0.983, 0.981]
# y_values_satlas = [0, 0.276, 0.367, 0.398, 0.414]

y_linear_values_ibot_imagenet = [0, 0.403, 0.747, 0.8944, 0.9159]
y_linear_values_ibot_milaid = [0, 0.2537, 0.6668, 0.9229, 0.9467]
y_linear_values_satlas_aerial = [0, 0.1506, 0.3114, 0.6559, 0.8175]
y_linear_values_gfm = [0, 0.3473, 0.6452, 0.836, 0.911]


y_finetune_values_ibot_imagenet = [0, 0.1597, 0.4284, 0.8373, 0.9375]
y_finetune_values_ibot_milaid = [0, 0.1668, 0.4052, 0.8344, 0.9322]
y_finetune_values_satlas_aerial = [0, 0.1917, 0.507, 0.8849, 0.9605]
y_finetune_values_gfm = [0, 0.2035, 0.6183, 0.884, 0.9546]

# Sort together by x-values
# sorted_data = sorted(zip(x_values, y_values))
# x_values, y_values = zip(*sorted_data)

# Calculate AUC using trapezoidal rule
auc_linear_ibot_imagenet = trapz(y_linear_values_ibot_imagenet, x_values)
auc_linear_ibot_milaid = trapz(y_linear_values_ibot_milaid, x_values)
auc_linear_satlas_aerial = trapz(y_linear_values_satlas_aerial, x_values)
auc_linear_gfm = trapz(y_linear_values_gfm, x_values)

auc_finetune_ibot_imagenet = trapz(y_finetune_values_ibot_imagenet, x_values)
auc_finetune_ibot_milaid = trapz(y_finetune_values_ibot_milaid, x_values)
auc_finetune_satlas_aerial = trapz(y_finetune_values_satlas_aerial, x_values)
auc_finetune_gfm = trapz(y_finetune_values_gfm, x_values)

# auc_satlas = trapz(y_values_satlas, x_values)

plt.figure(figsize=(4, 4))

# Plot the curve and points
plt.plot(x_values, y_linear_values_ibot_imagenet, label=f"iBOT-ImageNet ({auc_linear_ibot_imagenet:.3f})", marker='o', color='blue', linestyle='-', alpha=0.8, linewidth=1)
plt.plot(x_values, y_linear_values_ibot_milaid, label=f"iBOT-MillionAID ({auc_linear_ibot_milaid:.3f})", marker='o', color='orange', linestyle='-', alpha=0.8, linewidth=1)
plt.plot(x_values, y_linear_values_satlas_aerial, label=f"SatlasPretrain ({auc_linear_satlas_aerial:.3f})", marker='o', color='green', linestyle='-', alpha=0.8, linewidth=1)
plt.plot(x_values, y_linear_values_gfm, label=f"GFM ({auc_linear_gfm:.3f})", marker='o', color='red', linestyle='-', alpha=0.8, linewidth=1)

plt.plot(x_values, y_finetune_values_ibot_imagenet, label=f"iBOT-ImageNet ({auc_finetune_ibot_imagenet:.3f})", marker='o', color='blue', linestyle='-.', alpha=0.8, linewidth=1)
plt.plot(x_values, y_finetune_values_ibot_milaid, label=f"iBOT-MillionAID ({auc_finetune_ibot_milaid:.3f})", marker='o', color='orange', linestyle='-.', alpha=0.8, linewidth=1)
plt.plot(x_values, y_finetune_values_satlas_aerial, label=f"SatlasPretrain ({auc_finetune_satlas_aerial:.3f})", marker='o', color='green', linestyle='-.', alpha=0.8, linewidth=1)
plt.plot(x_values, y_finetune_values_gfm, label=f"GFM ({auc_finetune_gfm:.3f})", marker='o', color='red', linestyle='-.', alpha=0.8, linewidth=1)


# plt.plot(x_values, y_values_satlas, label=f"SATLAS ({auc_satlas:.3f})", marker='o')
# plt.scatter(x_values, y_values, label="Data Points")

# Add labels and title
plt.xlabel("Scale")
plt.ylabel("Accuracy")
plt.title("RESISC45")

# Show AUC value
# plt.text(0.7, 0.1, f"AUC: {auc:.3f}", ha="center", va="center", color='C0')
# plt.text(0.2, 0.4, f"AUC: {auc_aug:.3f}", ha="center", va="center", color='C1')

plt.legend(bbox_to_anchor=(0.05, -0.2), loc='upper left') 

# plt.legend(loc='outer')
plt.grid(True)
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.savefig('classification_resisc45.pdf', bbox_inches='tight') 
plt.show()
# Out:
# /tmp/ipykernel_2027803/1254748082.py:30: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_ibot_imagenet = trapz(y_linear_values_ibot_imagenet, x_values)
# /tmp/ipykernel_2027803/1254748082.py:31: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_ibot_milaid = trapz(y_linear_values_ibot_milaid, x_values)
# /tmp/ipykernel_2027803/1254748082.py:32: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_satlas_aerial = trapz(y_linear_values_satlas_aerial, x_values)
# /tmp/ipykernel_2027803/1254748082.py:33: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_gfm = trapz(y_linear_values_gfm, x_values)
# ...

# %%
# UCMerced

# Data points
x_values = [0, 1/8, 1/4, 1/2, 1]

# y_values_ibot_milaid = [0, 0.117, 0.510, 0.983, 0.988]
# y_values_gfm = [0, 0.433, 0.781, 0.914, 0.948]
# y_values_ibot_imagenet = [0, 0.652, 0.905, 0.983, 0.981]
# y_values_satlas = [0, 0.276, 0.367, 0.398, 0.414]


y_linear_values_ibot_imagenet = [0, 0.6738, 0.9095, 0.9738, 0.9762]
y_linear_values_ibot_milaid = [0, 0.3071, 0.7333, 0.9952, 0.9952]
y_linear_values_satlas_aerial = [0, 0.3667, 0.6548, 0.8643, 0.95]
y_linear_values_gfm = [0, 0.4738, 0.8429, 0.9381, 0.9571]


y_finetune_values_ibot_imagenet = [0, 0.5857, 0.9119, 0.9738, 0.9833]
y_finetune_values_ibot_milaid = [0, 0.4119, 0.7643, 0.9929, 0.9976]
y_finetune_values_satlas_aerial = [0, 0.5714, 0.9095, 0.9905, 0.9905]
y_finetune_values_gfm = [0, 0.6857, 0.9286, 0.9762, 0.9881]

# Sort together by x-values
# sorted_data = sorted(zip(x_values, y_values))
# x_values, y_values = zip(*sorted_data)

# Calculate AUC using trapezoidal rule
auc_linear_ibot_imagenet = trapz(y_linear_values_ibot_imagenet, x_values)
auc_linear_ibot_milaid = trapz(y_linear_values_ibot_milaid, x_values)
auc_linear_satlas_aerial = trapz(y_linear_values_satlas_aerial, x_values)
auc_linear_gfm = trapz(y_linear_values_gfm, x_values)

auc_finetune_ibot_imagenet = trapz(y_finetune_values_ibot_imagenet, x_values)
auc_finetune_ibot_milaid = trapz(y_finetune_values_ibot_milaid, x_values)
auc_finetune_satlas_aerial = trapz(y_finetune_values_satlas_aerial, x_values)
auc_finetune_gfm = trapz(y_finetune_values_gfm, x_values)

# auc_satlas = trapz(y_values_satlas, x_values)

plt.figure(figsize=(4, 4))

# Plot the curve and points
plt.plot(x_values, y_linear_values_ibot_imagenet, label=f"iBOT-ImageNet (frozen) ({auc_linear_ibot_imagenet:.3f})", marker='o', color='blue', linestyle='-', alpha=0.8, linewidth=1)
plt.plot(x_values, y_linear_values_ibot_milaid, label=f"iBOT-MillionAID (frozen) ({auc_linear_ibot_milaid:.3f})", marker='o', color='orange', linestyle='-', alpha=0.8, linewidth=1)
plt.plot(x_values, y_linear_values_satlas_aerial, label=f"SatlasPretrain (frozen) ({auc_linear_satlas_aerial:.3f})", marker='o', color='green', linestyle='-', alpha=0.8, linewidth=1)
plt.plot(x_values, y_linear_values_gfm, label=f"GFM (frozen) ({auc_linear_gfm:.3f})", marker='o', color='red', linestyle='-', alpha=0.8, linewidth=1)

plt.plot(x_values, y_finetune_values_ibot_imagenet, label=f"iBOT-ImageNet ({auc_finetune_ibot_imagenet:.3f})", marker='o', color='blue', linestyle='-.', alpha=0.8, linewidth=1)
plt.plot(x_values, y_finetune_values_ibot_milaid, label=f"iBOT-MillionAID ({auc_finetune_ibot_milaid:.3f})", marker='o', color='orange', linestyle='-.', alpha=0.8, linewidth=1)
plt.plot(x_values, y_finetune_values_satlas_aerial, label=f"SatlasPretrain ({auc_finetune_satlas_aerial:.3f})", marker='o', color='green', linestyle='-.', alpha=0.8, linewidth=1)
plt.plot(x_values, y_finetune_values_gfm, label=f"GFM ({auc_finetune_gfm:.3f})", marker='o', color='red', linestyle='-.', alpha=0.8, linewidth=1)


# plt.plot(x_values, y_values_satlas, label=f"SATLAS ({auc_satlas:.3f})", marker='o')
# plt.scatter(x_values, y_values, label="Data Points")

# Add labels and title
plt.xlabel("Scale")
plt.ylabel("Accuracy")
plt.title("UC Merced")

# Show AUC value
# plt.text(0.7, 0.1, f"AUC: {auc:.3f}", ha="center", va="center", color='C0')
# plt.text(0.2, 0.4, f"AUC: {auc_aug:.3f}", ha="center", va="center", color='C1')

plt.legend(bbox_to_anchor=(0.05, -0.2), loc='upper left') 

# plt.legend(loc='outer')
plt.grid(True)
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.savefig('classification_ucmerced.pdf', bbox_inches='tight') 
plt.show()
# Out:
# /tmp/ipykernel_2027803/3287250227.py:28: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_ibot_imagenet = trapz(y_linear_values_ibot_imagenet, x_values)
# /tmp/ipykernel_2027803/3287250227.py:29: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_ibot_milaid = trapz(y_linear_values_ibot_milaid, x_values)
# /tmp/ipykernel_2027803/3287250227.py:30: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_satlas_aerial = trapz(y_linear_values_satlas_aerial, x_values)
# /tmp/ipykernel_2027803/3287250227.py:31: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   auc_linear_gfm = trapz(y_linear_values_gfm, x_values)
# ...
